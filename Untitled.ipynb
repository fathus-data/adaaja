# %%
#Belajar dari W3schools

print("Hello Murni ?")   #Tahap 1
# Out:
# Hello Murni ?

# %%
if 5 > 2:
    print("lima lebih besar dari dua")    #Tahap 2
# Out:
# lima lebih besar dari dua

# %%
x = 108

y = 987

z = "Aku mencintaimu"

print(z)
print(type(y))    #Tahap 3
# Out:
# Aku mencintaimu
# <class 'int'>

# %%
x = 345

x = "Kapan kita kan bersama"

print(x)     #Tahap 4
# Out:
# Kapan kita kan bersama

# %%
x = str (8)

y = float (8)

z = int (8)

print(x)

print(y)

print(z)     #Tahap 5
# Out:
# 8
# 8.0
# 8

# %%
print(float(8))

print(int(48))     #Tahap 6
# Out:
# 8.0
# 48
